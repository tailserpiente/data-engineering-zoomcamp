# %%
from kafka import KafkaConsumer

server = 'localhost:9092'
#topic_name = 'rides'
topic_name = 'green-trips'

# %%
from models import Ride, ride_deserializer

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-database',
    value_deserializer=ride_deserializer
)

# %%
import psycopg2

conn = psycopg2.connect(
    host='localhost',
    port=5432,
    database='postgres',
    user='postgres',
    password='postgres'
)

conn.autocommit = True
cur = conn.cursor()

# %%
from datetime import datetime

print(f"Listening to {topic_name} and writing to PostgreSQL...")

count = 0
for message in consumer:
    ride = message.value
    pickup_dt = datetime.fromtimestamp(ride.lpep_pickup_datetime / 1000)
    cur.execute(
        """INSERT INTO processed_events
           (PULocationID, DOLocationID, trip_distance, total_amount, lpep_pickup_datetime )
           VALUES (%s, %s, %s, %s, %s)""",
        (ride.PULocationID, ride.DOLocationID,
         ride.trip_distance, ride.total_amount, pickup_dt)
    )
    count += 1
    if count % 10000 == 0:
        print(f"Inserted {count} rows...")

consumer.close()
cur.close()
conn.close()
# Out:
# Listening to green-trips and writing to PostgreSQL...
# Inserted 1000 rows...
# Inserted 2000 rows...
# Inserted 3000 rows...
# Inserted 4000 rows...
# Inserted 5000 rows...
# Inserted 6000 rows...
# Inserted 7000 rows...
# Inserted 8000 rows...
# Inserted 9000 rows...
# Inserted 10000 rows...
# Inserted 11000 rows...
# Inserted 12000 rows...
# Inserted 13000 rows...
# Inserted 14000 rows...
# Inserted 15000 rows...
# Inserted 16000 rows...
# Inserted 17000 rows...
# Inserted 18000 rows...
# Inserted 19000 rows...
# Inserted 20000 rows...
# Inserted 21000 rows...
# Inserted 22000 rows...
# Inserted 23000 rows...
# Inserted 24000 rows...
# Inserted 25000 rows...
# Inserted 26000 rows...
# Inserted 27000 rows...
# Inserted 28000 rows...
# Inserted 29000 rows...
# Inserted 30000 rows...
# Inserted 31000 rows...
# Inserted 32000 rows...
# Inserted 33000 rows...
# Inserted 34000 rows...
# Inserted 35000 rows...
# Inserted 36000 rows...
# Inserted 37000 rows...
# Inserted 38000 rows...
# Inserted 39000 rows...
# Inserted 40000 rows...
# Inserted 41000 rows...
# Inserted 42000 rows...
# Inserted 43000 rows...
# Inserted 44000 rows...
# Inserted 45000 rows...
# Inserted 46000 rows...
# Inserted 47000 rows...
# Inserted 48000 rows...
# Inserted 49000 rows...
# Inserted 50000 rows...
# Inserted 51000 rows...
# Inserted 52000 rows...
# Inserted 53000 rows...
# Inserted 54000 rows...
# Inserted 55000 rows...
# Inserted 56000 rows...
# Inserted 57000 rows...
# Inserted 58000 rows...
# Inserted 59000 rows...
# Inserted 60000 rows...
# Inserted 61000 rows...
# Inserted 62000 rows...
# Inserted 63000 rows...
# Inserted 64000 rows...
# Inserted 65000 rows...
# Inserted 66000 rows...
# Inserted 67000 rows...
# Inserted 68000 rows...
# Inserted 69000 rows...
# Inserted 70000 rows...
# Inserted 71000 rows...
# Inserted 72000 rows...
# Inserted 73000 rows...
# Inserted 74000 rows...
# Inserted 75000 rows...
# Inserted 76000 rows...
# Inserted 77000 rows...
# Inserted 78000 rows...
# Inserted 79000 rows...
# Inserted 80000 rows...
# Inserted 81000 rows...
# Inserted 82000 rows...
# Inserted 83000 rows...
# Inserted 84000 rows...
# Inserted 85000 rows...
# Inserted 86000 rows...
# Inserted 87000 rows...
# Inserted 88000 rows...
# Inserted 89000 rows...
# Inserted 90000 rows...
# Inserted 91000 rows...
# Inserted 92000 rows...
# Inserted 93000 rows...
# Inserted 94000 rows...
# Inserted 95000 rows...
# Inserted 96000 rows...
# Inserted 97000 rows...
# Inserted 98000 rows...
# Inserted 99000 rows...
# Inserted 100000 rows...
# Inserted 101000 rows...
# Inserted 102000 rows...
# Inserted 103000 rows...
# Inserted 104000 rows...
# Inserted 105000 rows...
# Inserted 106000 rows...
# Inserted 107000 rows...
# Inserted 108000 rows...
# Inserted 109000 rows...
# Inserted 110000 rows...
# Inserted 111000 rows...
# Inserted 112000 rows...
# Inserted 113000 rows...
# Inserted 114000 rows...
# Inserted 115000 rows...
# Inserted 116000 rows...
# Inserted 117000 rows...
# Inserted 118000 rows...
# Inserted 119000 rows...
# Inserted 120000 rows...
# Inserted 121000 rows...
# Inserted 122000 rows...
# Inserted 123000 rows...
# Inserted 124000 rows...
# Inserted 125000 rows...
# Inserted 126000 rows...
# Inserted 127000 rows...
# Inserted 128000 rows...
# Inserted 129000 rows...
# Inserted 130000 rows...
# Inserted 131000 rows...
# Inserted 132000 rows...
# Inserted 133000 rows...
# Inserted 134000 rows...
# Inserted 135000 rows...
# Inserted 136000 rows...
# Inserted 137000 rows...
# Inserted 138000 rows...
# Inserted 139000 rows...
# Inserted 140000 rows...
# Inserted 141000 rows...
# Inserted 142000 rows...
# Inserted 143000 rows...
# Inserted 144000 rows...
# Inserted 145000 rows...
# Inserted 146000 rows...
# Inserted 147000 rows...
# Inserted 148000 rows...
# Inserted 149000 rows...
# Inserted 150000 rows...
# Inserted 151000 rows...
# Inserted 152000 rows...
# Inserted 153000 rows...
# Inserted 154000 rows...
# Inserted 155000 rows...
# Inserted 156000 rows...
# Inserted 157000 rows...
# Inserted 158000 rows...
# Inserted 159000 rows...
# Inserted 160000 rows...
# Inserted 161000 rows...
# Inserted 162000 rows...
# Inserted 163000 rows...
# Inserted 164000 rows...
# Inserted 165000 rows...
# Inserted 166000 rows...
# Inserted 167000 rows...
# Inserted 168000 rows...
# Inserted 169000 rows...
# Inserted 170000 rows...
# Inserted 171000 rows...
# Inserted 172000 rows...
# Inserted 173000 rows...
# Inserted 174000 rows...
# Inserted 175000 rows...
# Inserted 176000 rows...
# Inserted 177000 rows...
# Inserted 178000 rows...
# Inserted 179000 rows...
# Inserted 180000 rows...
# Inserted 181000 rows...
# Inserted 182000 rows...
# Inserted 183000 rows...
# Inserted 184000 rows...
# Inserted 185000 rows...
# Inserted 186000 rows...
# Inserted 187000 rows...
# Inserted 188000 rows...
# Inserted 189000 rows...
# Inserted 190000 rows...
# Inserted 191000 rows...
# Inserted 192000 rows...
# Inserted 193000 rows...
# Inserted 194000 rows...
# Inserted 195000 rows...
# Inserted 196000 rows...
# Inserted 197000 rows...
# Inserted 198000 rows...
# Inserted 199000 rows...
# Inserted 200000 rows...
# Inserted 201000 rows...
# Inserted 202000 rows...
# Inserted 203000 rows...
# Inserted 204000 rows...
# Inserted 205000 rows...
# Inserted 206000 rows...
# Inserted 207000 rows...
# Inserted 208000 rows...
# Inserted 209000 rows...
# Inserted 210000 rows...
# Inserted 211000 rows...
# Inserted 212000 rows...
# Inserted 213000 rows...
# Inserted 214000 rows...
# Inserted 215000 rows...
# Inserted 216000 rows...
# Inserted 217000 rows...
# Inserted 218000 rows...
# Inserted 219000 rows...
# Inserted 220000 rows...
# Inserted 221000 rows...
# Inserted 222000 rows...
# Inserted 223000 rows...
# Inserted 224000 rows...
# Inserted 225000 rows...
# Inserted 226000 rows...
# Inserted 227000 rows...
# Inserted 228000 rows...
# Inserted 229000 rows...
# Inserted 230000 rows...
# Inserted 231000 rows...
# Inserted 232000 rows...
# Inserted 233000 rows...
# Inserted 234000 rows...
# Inserted 235000 rows...
# Inserted 236000 rows...
# Inserted 237000 rows...
# Inserted 238000 rows...
# Inserted 239000 rows...
# Inserted 240000 rows...
# Inserted 241000 rows...
# Inserted 242000 rows...
# Inserted 243000 rows...
# Inserted 244000 rows...
# Inserted 245000 rows...
# Inserted 246000 rows...
# Inserted 247000 rows...
# Inserted 248000 rows...
# Inserted 249000 rows...
